# %% [markdown]
# # GenAI WebScrapper

# %%
import os
from dotenv import load_dotenv
from langchain_community.llms import Ollama
import streamlit as st
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser


load_dotenv()

#os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
# prompt template

prompt=ChatPromptTemplate.from_messages([
    ("system","You are a helpful assistant that helps people find information."),
    ("user","Question:{question}")
    
])

# %%
#streamlit

st.title("GenAI WebScrapper with llama 3 model")
input_text=st.text_input("what question you have in your mind?")
# Out:
# 2025-09-08 17:52:16.141 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.229
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/ADML/Desktop/ML/GenAI/venv/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-09-08 17:52:16.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.240 Session state does not function when running a script without `streamlit run`
# 2025-09-08 17:52:16.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-08 17:52:16.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
llm=Ollama(model="llama3.2:latest")
output_parser=StrOutputParser()
chain=prompt | llm | output_parser

if input_text:
    st.write(chain.invoke({"question":input_text}))
# Out:
# /var/folders/kx/kjnz1_bs3rsgrlty_8pmtqqh0000gp/T/ipykernel_33286/3795176162.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm=Ollama(model="llama3.2:latest")
